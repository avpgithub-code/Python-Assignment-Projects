# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Sorting and Aggregating Data 📍 📍</h1></center>
#
# <center><h3>Submission from Archit Pandya</h3></center>
#
# ---
#
# #### `READ THE DATASET`
#
# ---

# %%
import pandas as pd
import datetime

# %%
data = pd.read_csv('dataset/time_series.csv')

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %% [markdown]
# #### `Convert the Datetime column to pandas datetime object`
#
# ---

# %%
# WRITE YOUR CODE HERE
data['Datetime'] = pd.to_datetime(data['Datetime'], format= '%d-%m-%Y %H:%M')
data.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
data.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %% [markdown]
# ---
#
# ####  `Create the following features using the Datetime feature`
#
# - day of month
# - month
# - day of year
# - hour
#
# ---

# %%
# WRITE YOUR CODE HERE

data['Day_Of_Month'] = data.Datetime.dt.day.tolist()
data['Month'] = data.Datetime.dt.month
data['Day_Of_Month'] = data.Datetime.dt.dayofyear.tolist()
data['Hour'] = data.Datetime.dt.hour

# %%
data.head()
# Out:
#    ID            Datetime  Count  Day_Of_Month  Month  Hour
# 0   0 2012-08-25 00:00:00      8           238      8     0
# 1   1 2012-08-25 01:00:00      2           238      8     1
# 2   2 2012-08-25 02:00:00      6           238      8     2
# 3   3 2012-08-25 03:00:00      2           238      8     3
# 4   4 2012-08-25 04:00:00      2           238      8     4

# %% [markdown]
# ---
#
# #### `Consider the following dataframe`
#
# ---

# %%
sample_df = pd.DataFrame({
    'id'   :  [1, 2, 3, 4, 5],
    'name' :  [ 'Akash', 'Akansha', 'Naman', 'Pulkit', 'Anand'],
    'marks':  [ 22, 23, 43, 41, 12]
})
sample_df
# Out:
#    id     name  marks
# 0   1    Akash     22
# 1   2  Akansha     23
# 2   3    Naman     43
# 3   4   Pulkit     41
# 4   5    Anand     12

# %% [markdown]
# #### Sort the  dataframe by `marks` column in descending order
#
# ---

# %%
# WRITE YOUR CODE HERE
sample_df.sort_values(by = 'marks', ascending = False)
# Out:
#    id     name  marks
# 2   3    Naman     43
# 3   4   Pulkit     41
# 1   2  Akansha     23
# 0   1    Akash     22
# 4   5    Anand     12

# %% [markdown]
# #### Consider another dataframe city
# ---

# %%
city = pd.DataFrame({
    'name' : ['Akash', 'Akansha', 'Pulkit', 'Anand', 'Naman'],
    'city' : ['Delhi', 'Gurugram', 'Gurugram', 'Delhi', 'Noida']
})
city
# Out:
#       name      city
# 0    Akash     Delhi
# 1  Akansha  Gurugram
# 2   Pulkit  Gurugram
# 3    Anand     Delhi
# 4    Naman     Noida

# %% [markdown]
# ***Use the dataframe `sample_df` and `city` and find out the marks of students who live in Gurugram.***
#
# ---

# %%
### Write your code here

name_city = sample_df.merge(city, how = 'inner', on = 'name', sort = 'name')
name_city.query("city == 'Gurugram'")
# Out:
#    id     name  marks      city
# 0   2  Akansha     23  Gurugram
# 4   4   Pulkit     41  Gurugram

# %% [markdown]
# #### `READ THE BIG MART SALES DATA`
#
# ---

# %%
big_mart_data = pd.read_csv('dataset/big_mart_sales.csv')

# %%
big_mart_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### Find out the number of unique `Item_Type` in each of the `Outlet_Identifier`
#
# ---

# %%
# WRITE YOUR CODE HERE
pd.crosstab(big_mart_data['Outlet_Identifier'], big_mart_data['Item_Type'])
# Out:
# Item_Type          Baking Goods  Breads  Breakfast  Canned  Dairy  \
# Outlet_Identifier
# OUT010                       42      17          9      35     43
# OUT013                       73      25         13      65     80
# OUT017                       73      22         12      69     74
# OUT018                       68      27         12      78     73
# OUT019                       43      16         10      38     49
# OUT027                       69      31         11      72     67
# OUT035                       68      29         10      79     71
# OUT045                       70      33         10      74     69
# OUT046                       76      26         10      72     78
# OUT049                       66      25         13      67     78
#
# Item_Type          Frozen Foods  Fruits and Vegetables  Hard Drinks  \
# Outlet_Identifier
# OUT010                       54                     79           16
# ...

# %%
# OR Another way to provide using GroupBy

num_of_unique_item_type_by_outlet = big_mart_data.groupby(['Outlet_Identifier','Item_Type']).count()['Item_Identifier']
num_of_unique_item_type_by_outlet
# Out:
# Outlet_Identifier  Item_Type
# OUT010             Baking Goods      42
#                    Breads            17
#                    Breakfast          9
#                    Canned            35
#                    Dairy             43
#                                    ...
# OUT049             Others            17
#                    Seafood            7
#                    Snack Foods      139
#                    Soft Drinks       46
#                    Starchy Foods     17
# Name: Item_Identifier, Length: 160, dtype: int64

# %% [markdown]
# #### Find out the average `Item_Outlet_Sales` for each category of `Outlet_Size`
#
# ---

# %%
# WRITE YOUR CODE HERE

avg_item_outlet_sales = big_mart_data.groupby(['Outlet_Size'])['Item_Outlet_Sales'].mean()
avg_item_outlet_sales
# Out:
# Outlet_Size
# High      2298.995256
# Medium    2681.603542
# Small     1912.149161
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### Select only the categorical variables from the dataframe and use `get_dummies` function to convert those into the numerical ones.
#
# ---

# %%
# WRITE YOUR CODE HERE

# %%
# Creaate list of categorical columns per below 
cat_columns = [col for col in big_mart_data.columns if big_mart_data[col].dtype == 'object']
cat_columns
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
# Shape of the dataframe prior to running 'Get_Dummies'

big_mart_data.shape
# Out:
# (8523, 12)

# %%
# Convert categorical values into numerical using below call
big_mart_data_no_categorical = pd.get_dummies(big_mart_data[cat_columns])

# %%
big_mart_data_no_categorical.head()
# Out:
#    Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Item_Identifier_DRB25  Item_Identifier_DRB48  Item_Identifier_DRC01  \
# ...
